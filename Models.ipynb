# %% [markdown]
# # TU Admissions Modeling

# %%
# Importing all necessary packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import boxcox
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error, cohen_kappa_score
import statsmodels.api as sm
import pingouin as pg
import pickle as pk
import warnings

# Configuring warnings and display settings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %% [markdown]
# # TU Admissions Brief Write Up
# ### Introduction
# The ultimate goal of this project was to construct a classification model to determine whether an accepted applicant will decide to attend the University. Determining why some applicants accept and some do not can be valuable to the Office of Admission to further enhance the yield, which is defined as the number of applicants who accepted the offer of admission to attend the University. The project is about designing a classification model which determines whether an applicant accepted will or will not attend Trinity University.
#
# ### Dataset Overview
# The dataset includes multiple variables on applicants who have been accepted to Trinity University. In this regard, it contains a set of personal, academic, and demographic information that might affect an applicant's choice to join the university. The dataset ranges over five entry terms, starting from Fall 2017 through Fall 2021.  The response variable, "Decision," measures the decision of an applicant as accepted offer to enroll = 1 and did not accept the offer = 0. First of all, the clean and pre-processing steps have to be made regarding the data to provide accurate and meaningful results using a machine learning model.
#
# ### Best Model and Most Important Features Discussion
# Boosting ended up being my best model with a train kappa of 0.570 and a test kappa of 0.514. Total Event Participation, Count of Campus Visits, Athlete_Athlete,Legacy, and Academic Index, were all among my most important features in my modeling stage.
# 1) The most significant predictor of enrollment decisions from was Total Event Participation, with a Gini of 0.360977. This showed that applicants who are more engaged with university activities are more likely to accept an offer of admission. This indicates that early engagement is very important and should be fostered through both virtual and in-person events. The admissions team should therefore focus on creating more interactive opportunities like webinars, open houses, and campus tours. Moreover, the trend of participation in these events could give much insight into applicants' enrollment probability so that follow-up communications might be more effectively tailored to individual needs. Decision yield might also be improved due to better experiences during a campus visit-for example, if a tour was personalized or conducted by an officer of admission for a more quality experience.
# 2) Other high value features included Campus Visits (Gini: 0.151382) and Decision Plan (Early Decision I and II) Gini: 0.124239, 0.052272. As illustrated by the data, applicants who visit campus are more likely to accept the offer. These data, therefore, indicate that the admission team should focus their efforts on attracting visitors to campus. Targeted invitations, travel stipends, and special events for visitors may be other strategies that could encourage visits. Also, the applicants applying under early decision plans are likely to enroll, as early decision is a binding commitment. Thus, by increasing outreach to early decision applicants and offering them special support and incentives, the likelihood of these students submitting early decision can be increased.
# 3) Lastly, factors such as Legacy (Gini: 0.039456) and Academic Index (Gini: 0.033812) suggest that personalized outreach to high-potential applicants can significantly impact yield. The Legacy applicants, connected to the university through families, were more likely to enroll. Thus, selective communications or events may help enhance this population's attachment to the university. For example, there could be events for alumni who are within a certain age range that encourage bringing their kids to learn about going to Trinity. Similarly, higher-index students were more likely to attend; focusing recruiting efforts on the highest-achieving students, including through honors programs, scholarship offers, and personal contact with recruitment staff, has the potential to increase the institution's yield. Furthermore, the value of the Merit Award Full Ride is very important, given the Gini of 0.010574, representing that financial aid, to be more specific-full ride scholarships, play a vital role in the decision-making of the applicants. To this point, the admissions team may work on enhancing financial aid packages and making these more visible to top candidates during the early stages of the process.

# %% [markdown]
# #  Refinement

# %% [markdown]
# ### Reading in data

# %%
#import train
df_train=pd.read_csv('cleaneddftrain.csv', index_col='ID')
train = df_train.drop(columns='Unnamed: 0')

# %%
#import test
df_test=pd.read_csv('cleaneddftest.csv', index_col='ID')
test = df_test.drop(columns='Unnamed: 0')

# %%
missing_in_train = set(test.columns) - set(train.columns)
missing_in_test = set(train.columns) - set(test.columns)

print("Missing in train:", missing_in_train)
print("Missing in test:", missing_in_test)
# Out:
# Missing in train: set()
# Missing in test: set()

# %%
# List of columns to drop (in this case, 'Decision', 'const', and 'train-test')
columns_to_drop = ['Decision', 'train-test']

# Drop unnecessary columns from both train and test sets in one step
x_train = sm.add_constant(train.drop(columns=columns_to_drop))
x_test = sm.add_constant(test.drop(columns=columns_to_drop))

# remove const

x_train = x_train.drop(columns = 'const') 
x_test = x_test.drop(columns = 'const')

# Extract target variable separately
y_train = train['Decision']
y_test = test['Decision']

# %%
x_train.columns
# Out:
# Index(['Entry Term (Application)', 'Permanent Country', 'Sex', 'Ethnicity',
#        'Race', 'Religion', 'Application Source', 'Decision Plan', 'Legacy',
#        'Athlete', 'Sport 1 Sport', 'Sport 1 Rating', 'Sport 2 Sport',
#        'Sport 3 Sport', 'Academic Interest 1', 'Academic Interest 2',
#        'First_Source Origin First Source Summary', 'Total Event Participation',
#        'Count of Campus Visits', 'School 1 Class Rank (Numeric)',
#        'School 1 Class Size (Numeric)', 'School 1 GPA Recalculated',
#        'ACT Composite',
#        'SAT R Evidence-Based Reading and Writing Section + Math Section',
#        'Permanent Geomarket', 'Citizenship Status', 'Academic Index',
#        'Intend to Apply for Financial Aid?', 'Merit Award',
#        'Submit_FirstSource', 'Submit_Inquiry', 'School 1 Top Percent in Class',
#        'ACT Composite Grouped'],
#       dtype='object')

# %% [markdown]
# ### Creating new variable to handle Submit_Inquiry and Submit_FirstSource, will then make the column ordinal

# %%
x_train['Days_to_Submit_since_Inquiry'] = x_train['Submit_Inquiry'] - x_train['Submit_FirstSource']

# %%
x_test['Days_to_Submit_since_Inquiry'] = x_test['Submit_Inquiry'] - x_test['Submit_FirstSource']

# %%
ordinal_cols = ['Legacy','Sport 1 Rating','Count of Campus Visits','Total Event Participation',
               'Days_to_Submit_since_Inquiry']

def encodetrain(x_train, ordinal_columns=None):
    # If ordinal columns are not provided, you could define a default list or handle it dynamically
    if ordinal_columns is None:
        ordinal_columns = []  # Adjust this list if you have predefined ordinal columns

    # Loop through columns
    for col in x_train.columns:
        if x_train[col].dtype == 'object' or x_train[col].dtype == 'category':
            # Check if it's an ordinal column
            if col in ordinal_columns:
                le = LabelEncoder()
                x_train[col] = le.fit_transform(x_train[col])
            else:
                # Non-ordinal categorical, apply one-hot encoding
                x_train = pd.get_dummies(x_train, columns=[col], drop_first=True)

    return x_train

x_train = encodetrain(x_train, ordinal_columns=ordinal_cols)

# %%
def encodetest(x_test, ordinal_columns=None):
    # If ordinal columns are not provided, you could define a default list or handle it dynamically
    if ordinal_columns is None:
        ordinal_columns = []  # Adjust this list if you have predefined ordinal columns

    # Loop through columns
    for col in x_test.columns:
        if x_test[col].dtype == 'object' or x_test[col].dtype == 'category':
            # Check if it's an ordinal column
            if col in ordinal_columns:
                le = LabelEncoder()
                x_test[col] = le.fit_transform(x_test[col])
            else:
                # Non-ordinal categorical, apply one-hot encoding
                x_test = pd.get_dummies(x_test, columns=[col], drop_first=True)

    return x_test

x_test = encodetest(x_test, ordinal_columns=ordinal_cols)

# %% [markdown]
# ### Removing variables with correlations lower than 0.015

# %%
# Dictionary to store correlations
correlations = {}

# Loop to calculate correlations and store them
for col in x_train.columns:
    correlation = x_train[col].corr(y_train)  # Calculate correlation with y_train
    correlations[col] = correlation

# Filter out columns with correlation less than 0.015
columns_to_remove = [col for col, corr in correlations.items() if abs(corr) < 0.015]

# Remove columns from x_train that have low correlation
x_train = x_train.drop(columns=columns_to_remove)
x_test = x_test.drop(columns=columns_to_remove)

# Print the columns that were removed
print(f'Columns removed due to low correlation: {columns_to_remove}')
# Out:
# Columns removed due to low correlation: ['School 1 Class Size (Numeric)', 'Submit_FirstSource', 'Entry Term (Application)_Fall 2019', 'Entry Term (Application)_Fall 2020', 'Entry Term (Application)_Fall 2021', 'Permanent Country_Belgium', 'Permanent Country_Belize', 'Permanent Country_Bolivia', 'Permanent Country_Brazil', 'Permanent Country_Cambodia', 'Permanent Country_Canada', 'Permanent Country_China', 'Permanent Country_Colombia', 'Permanent Country_Costa Rica', 'Permanent Country_Ecuador', 'Permanent Country_Ethiopia', 'Permanent Country_France', 'Permanent Country_Germany', 'Permanent Country_Ghana', 'Permanent Country_Greece', 'Permanent Country_Guatemala', 'Permanent Country_Honduras', 'Permanent Country_Hong Kong S.A.R.', 'Permanent Country_Indonesia', 'Permanent Country_Japan', 'Permanent Country_Jordan', 'Permanent Country_Kazakhstan', 'Permanent Country_Kuwait', 'Permanent Country_Lebanon', 'Permanent Country_Mexico', 'Permanent Country_Morocco', 'Permanent Country_Nepal', 'Permanent Country_Netherlands', 'Permanent Country_Nicaragua', 'Permanent Country_Nigeria', 'Permanent Country_Norway', 'Permanent Country_Pakistan', 'Permanent Country_Panama', 'Permanent Country_Peru', 'Permanent Country_Philippines', 'Permanent Country_Russia', 'Permanent Country_Saudi Arabia', 'Permanent Country_Singapore', 'Permanent Country_South Africa', 'Permanent Country_South Korea', 'Permanent Country_Spain', 'Permanent Country_Switzerland', 'Permanent Country_Taiwan', 'Permanent Country_Tanzania', 'Permanent Country_Thailand', 'Permanent Country_Turkey', 'Permanent Country_UniqueCountry', 'Permanent Country_United Arab Emirates', 'Permanent Country_United Kingdom', 'Permanent Country_Uruguay', 'Permanent Country_Vietnam', 'Sex_M', 'Ethnicity_Non Hispanic/Latino', 'Ethnicity_Not specified', 'Race_Asian, White', 'Race_Black or African American, White', 'Race_Not specified', 'Race_Others', 'Religion_Baptist', 'Religion_Islam/Muslim', 'Religion_Jewish', 'Religion_Non-Denominational', 'Religion_Presbyterian', 'Religion_Roman Catholic', 'Decision Plan_Early Action II', 'Academic Interest 1_Biochemistry & Molecular Biology', 'Academic Interest 1_Biology', 'Academic Interest 1_Business', 'Academic Interest 1_Business - Accounting', 'Academic Interest 1_Business - Communication Management', 'Academic Interest 1_Business - Marketing', 'Academic Interest 1_Chemistry', 'Academic Interest 1_Computer Science', 'Academic Interest 1_Economics', 'Academic Interest 1_Education', 'Academic Interest 1_English', 'Academic Interest 1_International Studies', 'Academic Interest 1_Neuroscience', 'Academic Interest 1_Others', 'Academic Interest 1_Physics', 'Academic Interest 1_Pre-Law', 'Academic Interest 2_Biology', 'Academic Interest 2_Business - Accounting', 'Academic Interest 2_Business - International Business', 'Academic Interest 2_Business - Management', 'Academic Interest 2_Business - Marketing', 'Academic Interest 2_Chemistry', 'Academic Interest 2_Computer Science', 'Academic Interest 2_Economics', 'Academic Interest 2_Education', 'Academic Interest 2_Engineering Science', 'Academic Interest 2_English', 'Academic Interest 2_Environmental Studies', 'Academic Interest 2_History', 'Academic Interest 2_International Studies', 'Academic Interest 2_Mathematics', 'Academic Interest 2_Neuroscience', 'Academic Interest 2_Physics', 'Academic Interest 2_Political Science', 'Academic Interest 2_Pre-Law', 'Academic Interest 2_Sociology', 'Academic Interest 2_Undecided', 'First_Source Origin First Source Summary_CAPIQ', 'First_Source Origin First Source Summary_HSV', 'First_Source Origin First Source Summary_PSAT', 'First_Source Origin First Source Summary_SATR', 'First_Source Origin First Source Summary_SIB', 'Permanent Geomarket_Midwest', 'ACT Composite Grouped_30.0', 'ACT Composite Grouped_31.0', 'ACT Composite Grouped_32.0']

# %% [markdown]
# ### Binning variables

# %%
x_train.columns
# Out:
# Index(['Legacy', 'Sport 1 Rating', 'Total Event Participation',
#        'Count of Campus Visits', 'School 1 Class Rank (Numeric)',
#        'School 1 GPA Recalculated', 'ACT Composite',
#        'SAT R Evidence-Based Reading and Writing Section + Math Section',
#        'Academic Index', 'Intend to Apply for Financial Aid?',
#        'Submit_Inquiry', 'School 1 Top Percent in Class',
#        'Days_to_Submit_since_Inquiry', 'Entry Term (Application)_Fall 2018',
#        'Permanent Country_Cyprus', 'Permanent Country_El Salvador',
#        'Permanent Country_India', 'Permanent Country_Jamaica',
#        'Permanent Country_United States', 'Race_Asian',
#        'Race_Black or African American', 'Race_White', 'Religion_Christian',
#        'Religion_Hindu', 'Religion_Lutheran', 'Religion_Methodist',
#        'Religion_Not specified', 'Religion_OtherRelgiousAffiliation',
#        'Application Source_Coalition', 'Application Source_CommonApp',
#        'Application Source_Select Scholar', 'Decision Plan_Early Action I',
#        'Decision Plan_Early Decision I', 'Decision Plan_Early Decision II',
#        'Decision Plan_Regular Decision', 'Athlete_Athlete, Opt Out',
#        'Athlete_Non-Athlete', 'Sport 1 Sport_Cross Country',
#        'Sport 1 Sport_Diving', 'Sport 1 Sport_Golf', 'Sport 1 Sport_No Sport',
#        'Sport 1 Sport_Soccer', 'Sport 1 Sport_Sport', 'Sport 1 Sport_Swimming',
#        'Sport 1 Sport_Tennis', 'Sport 1 Sport_Track',
#        'Sport 2 Sport_No 2ndSport', 'Sport 3 Sport_No 3rdSport',
#        'Academic Interest 1_Business - International Business',
#        'Academic Interest 1_Business - Management',
#        'Academic Interest 1_Communication',
#        'Academic Interest 1_Engineering Science',
#        'Academic Interest 1_Environmental Studies',
#        'Academic Interest 1_History', 'Academic Interest 1_Mathematics',
#        'Academic Interest 1_Political Science',
#        'Academic Interest 1_Pre-Medical', 'Academic Interest 1_Psychology',
#        'Academic Interest 1_Undecided',
#        'Academic Interest 2_Biochemistry & Molecular Biology',
#        'Academic Interest 2_Business', 'Academic Interest 2_Others',
#        'Academic Interest 2_Pre-Medical', 'Academic Interest 2_Psychology',
#        'First_Source Origin First Source Summary_ATH',
#        'First_Source Origin First Source Summary_CAP',
#        'First_Source Origin First Source Summary_CBINQ',
#        'First_Source Origin First Source Summary_CF',
#        'First_Source Origin First Source Summary_OAPP',
#        'First_Source Origin First Source Summary_Other Sources',
#        'First_Source Origin First Source Summary_SRCH',
#        'First_Source Origin First Source Summary_TIF',
#        'First_Source Origin First Source Summary_VST',
#        'First_Source Origin First Source Summary_WEBTU',
#        'First_Source Origin First Source Summary_YUVST',
#        'Permanent Geomarket_Northeast', 'Permanent Geomarket_South',
#        'Permanent Geomarket_West', 'Citizenship Status_Permanent Resident',
#        'Citizenship Status_US Citizen', 'Merit Award_Full Ride',
#        'Merit Award_International Student Scholarship',
#        'Merit Award_No Merit Scholarship', 'ACT Composite Grouped_23.0',
#        'ACT Composite Grouped_24.0', 'ACT Composite Grouped_25.0',
#        'ACT Composite Grouped_26.0', 'ACT Composite Grouped_27.0',
#        'ACT Composite Grouped_28.0', 'ACT Composite Grouped_29.0',
#        'ACT Composite Grouped_33.0', 'ACT Composite Grouped_34.0',
#        'ACT Composite Grouped_35.0', 'ACT Composite Grouped_36.0',
#        'ACT Composite Grouped_ACTBelow21'],
#       dtype='object')

# %%
x_train['School 1 GPA Recalculated'].describe()
# Out:
# count    10000.000000
# mean         3.701429
# std          0.292452
# min          2.330000
# 25%          3.500000
# 50%          3.790000
# 75%          3.960000
# max          4.000000
# Name: School 1 GPA Recalculated, dtype: float64

# %%
# Create bins from 0 to 4 with 0.25 intervals
bins = np.arange(0, 4.25, 0.25)  # 4.25 ensures 4.0 is included

# Define labels for each 0.25 interval
labels = [f"{i}-{i+0.25}" for i in bins[:-1]]  # Generate labels like '0-0.25', '0.25-0.5', etc.

# Apply pd.cut with these bins and labels
x_train['GPA_category'] = pd.cut(x_train['School 1 GPA Recalculated'], bins=bins, labels=labels, right=False)
x_test['GPA_category'] = pd.cut(x_test['School 1 GPA Recalculated'], bins=bins, labels=labels, right=False)

# %%
x_train['School 1 Class Rank (Numeric)'].describe()
# Out:
# count    4643.000000
# mean       62.093905
# std        78.059632
# min         1.000000
# 25%         9.000000
# 50%        33.000000
# 75%        83.000000
# max       655.000000
# Name: School 1 Class Rank (Numeric), dtype: float64

# %%
# Create bins from 0 to 700 with a step size of 100
bins = np.arange(0, 701, 100)  # 701 ensures 700 is included

# Define labels for each 100-step interval
labels = [f"{i}-{i+100}" for i in bins[:-1]]  # Generate labels like '0-100', '100-200', etc.

# Apply pd.cut with these bins and labels
x_train['Class_Rank_Category'] = pd.cut(x_train['School 1 Class Rank (Numeric)'], bins=bins, labels=labels, right=False)
x_test['Class_Rank_Category'] = pd.cut(x_test['School 1 Class Rank (Numeric)'], bins=bins, labels=labels, right=False)

# %%
x_train['School 1 Top Percent in Class'].describe()
# Out:
# count    10000.000000
# mean        13.371305
# std         10.331136
# min          0.101729
# 25%          4.614411
# 50%         10.952852
# 75%         16.109453
# max        100.000000
# Name: School 1 Top Percent in Class, dtype: float64

# %%
# Create bins from 0 to 100 with a step size of 5
bins = np.arange(0, 105, 5)  # 105 ensures 100 is included

# Define labels for each 5-step interval
labels = [f"{i}-{i+5}" for i in bins[:-1]]  # Generate labels like '0-5', '5-10', etc.

# Apply pd.cut with these bins and labels
x_train['Top_Percent_Category'] = pd.cut(x_train['School 1 Top Percent in Class'], bins=bins, labels=labels, right=False)
x_test['Top_Percent_Category'] = pd.cut(x_test['School 1 Top Percent in Class'], bins=bins, labels=labels, right=False)

# %% [markdown]
# ### Dropping similar variables

# %%
# List of columns to drop
columns_to_drop = ['School 1 Class Rank (Numeric)', 
                   'School 1 GPA Recalculated','ACT Composite',
                   'SAT R Evidence-Based Reading and Writing Section + Math Section',
                   'School 1 Top Percent in Class','Submit_Inquiry']

# Drop columns in place
x_train.drop(columns=columns_to_drop, inplace=True)
x_test.drop(columns=columns_to_drop, inplace=True)

# %%
missing_in_train = set(x_test.columns) - set(x_train.columns)
missing_in_test = set(x_train.columns) - set(x_test.columns)

print("Missing in train:", missing_in_train)
print("Missing in test:", missing_in_test)
# Out:
# Missing in train: {'Permanent Geomarket_Unknown'}
# Missing in test: set()

# %%
x_test = x_test.drop(columns='Permanent Geomarket_Unknown')

# %% [markdown]
# ### Ensuring Correct Variable Coding

# %%
ordinal_cols = ['Legacy','Sport 1 Rating','Count of Campus Visits','Total Event Participation'
               ]

def dummytrain(x_train, ordinal_columns=None):
    # Loop through columns
    for col in x_train.columns:
        if x_train[col].dtype == 'object' or x_train[col].dtype == 'category':
            # Check if it's an ordinal column
            if col in ordinal_columns:
                le = LabelEncoder()
                x_train[col] = le.fit_transform(x_train[col])
            else:
                # Non-ordinal categorical, apply one-hot encoding
                x_train = pd.get_dummies(x_train, columns=[col], dtype=int, drop_first=True)
        
        # Handle boolean columns (True/False -> 1/0)
        elif x_train[col].dtype == 'bool':
            x_train[col] = x_train[col].astype(int)

    return x_train

x_train = dummytrain(x_train, ordinal_columns=ordinal_cols)

# %%
def dummytest(x_test, ordinal_columns=None):
    # Loop through columns
    for col in x_test.columns:
        if x_test[col].dtype == 'object' or x_test[col].dtype == 'category':
            # Check if it's an ordinal column
            if col in ordinal_columns:
                le = LabelEncoder()
                x_test[col] = le.fit_transform(x_test[col])
            else:
                # Non-ordinal categorical, apply one-hot encoding
                x_test = pd.get_dummies(x_test, columns=[col], dtype=int, drop_first=True)
        
        # Handle boolean columns (True/False -> 1/0)
        elif x_test[col].dtype == 'bool':
            x_test[col] = x_test[col].astype(int)

    return x_test

x_test = dummytest(x_test, ordinal_columns=ordinal_cols)

# %%
missing_in_train = set(x_test.columns) - set(x_train.columns)
missing_in_test = set(x_train.columns) - set(x_test.columns)

print("Missing in train:", missing_in_train)
print("Missing in test:", missing_in_test)
# Out:
# Missing in train: set()
# Missing in test: set()

# %% [markdown]
# ## Logistic Model

# %%
# Passing VIF scores

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['variable'] = x_train.columns
vif[:]
# Out:
#             VIF                                           variable
# 0     18.074502                                             Legacy
# 1     18.400583                                     Sport 1 Rating
# 2      1.654042                          Total Event Participation
# 3      1.492536                             Count of Campus Visits
# 4     41.411248                                     Academic Index
# 5      3.335852                 Intend to Apply for Financial Aid?
# 6      1.553281                       Days_to_Submit_since_Inquiry
# 7      1.430814                 Entry Term (Application)_Fall 2018
# 8      1.012958                           Permanent Country_Cyprus
# 9      1.026283                      Permanent Country_El Salvador
# 10     1.167067                            Permanent Country_India
# 11     1.038178                          Permanent Country_Jamaica
# 12    69.408834                    Permanent Country_United States
# 13     2.843940                                         Race_Asian
# 14     1.546089                     Race_Black or African American
# 15     7.582251                                         Race_White
# 16     1.377618                                 Religion_Christian
# 17     1.296055                                     Religion_Hindu
# 18     1.084760                                  Religion_Lutheran
# 19     1.159250                                 Religion_Methodist
# 20     2.539556                             Religion_Not specified
# 21     1.252465                  Religion_OtherRelgiousAffiliation
# 22     1.143845                       Application Source_Coalition
# 23     5.824695                       Application Source_CommonApp
# 24     1.538951                  Application Source_Select Scholar
# 25     2.098960                       Decision Plan_Early Action I
# 26     1.182664                     Decision Plan_Early Decision I
# 27     1.085476                    Decision Plan_Early Decision II
# 28     1.611099                     Decision Plan_Regular Decision
# 29     1.481403                           Athlete_Athlete, Opt Out
# 30          inf                                Athlete_Non-Athlete
# 31     2.594488                        Sport 1 Sport_Cross Country
# 32     1.225403                               Sport 1 Sport_Diving
# 33     1.340763                                 Sport 1 Sport_Golf
# 34          inf                             Sport 1 Sport_No Sport
# 35     2.463689                               Sport 1 Sport_Soccer
# 36     5.610410                                Sport 1 Sport_Sport
# 37     2.144327                             Sport 1 Sport_Swimming
# 38     1.627550                               Sport 1 Sport_Tennis
# 39     2.534395                                Sport 1 Sport_Track
# 40    50.299077                          Sport 2 Sport_No 2ndSport
# 41    98.141195                          Sport 3 Sport_No 3rdSport
# 42     1.046638  Academic Interest 1_Business - International B...
# 43     1.072991          Academic Interest 1_Business - Management
# 44     1.044887                  Academic Interest 1_Communication
# 45     1.171642            Academic Interest 1_Engineering Science
# 46     1.043861          Academic Interest 1_Environmental Studies
# 47     1.044582                        Academic Interest 1_History
# 48     1.053400                    Academic Interest 1_Mathematics
# 49     1.099342              Academic Interest 1_Political Science
# 50     1.243471                    Academic Interest 1_Pre-Medical
# 51     1.122497                     Academic Interest 1_Psychology
# 52     1.089455                      Academic Interest 1_Undecided
# 53     1.095890  Academic Interest 2_Biochemistry & Molecular B...
# 54     1.187794                       Academic Interest 2_Business
# 55     1.333496                         Academic Interest 2_Others
# 56     1.132094                    Academic Interest 2_Pre-Medical
# 57     1.110517                     Academic Interest 2_Psychology
# 58     1.302251       First_Source Origin First Source Summary_ATH
# 59     1.439708       First_Source Origin First Source Summary_CAP
# 60     5.075414     First_Source Origin First Source Summary_CBINQ
# 61     1.284990        First_Source Origin First Source Summary_CF
# 62     1.908327      First_Source Origin First Source Summary_OAPP
# 63     1.459959  First_Source Origin First Source Summary_Other...
# 64     1.532091      First_Source Origin First Source Summary_SRCH
# 65     1.174203       First_Source Origin First Source Summary_TIF
# 66     1.421454       First_Source Origin First Source Summary_VST
# 67     1.263694     First_Source Origin First Source Summary_WEBTU
# 68     1.107563     First_Source Origin First Source Summary_YUVST
# 69     1.555023                      Permanent Geomarket_Northeast
# 70    18.628554                          Permanent Geomarket_South
# 71     4.226152                           Permanent Geomarket_West
# 72     6.459891              Citizenship Status_Permanent Resident
# 73   227.944405                      Citizenship Status_US Citizen
# 74     1.061753                              Merit Award_Full Ride
# 75    12.136624      Merit Award_International Student Scholarship
# 76     1.531924                   Merit Award_No Merit Scholarship
# 77     1.129543                         ACT Composite Grouped_23.0
# 78     1.126613                         ACT Composite Grouped_24.0
# 79     1.158777                         ACT Composite Grouped_25.0
# 80     1.186804                         ACT Composite Grouped_26.0
# 81     1.262045                         ACT Composite Grouped_27.0
# 82     1.271442                         ACT Composite Grouped_28.0
# 83     1.269802                         ACT Composite Grouped_29.0
# 84     1.338889                         ACT Composite Grouped_33.0
# 85     1.372845                         ACT Composite Grouped_34.0
# 86     1.318435                         ACT Composite Grouped_35.0
# 87     1.106079                         ACT Composite Grouped_36.0
# 88     1.100997                   ACT Composite Grouped_ACTBelow21
# 89          NaN                              GPA_category_0.25-0.5
# 90          NaN                              GPA_category_0.5-0.75
# 91          NaN                              GPA_category_0.75-1.0
# 92          NaN                              GPA_category_1.0-1.25
# 93          NaN                              GPA_category_1.25-1.5
# 94          NaN                              GPA_category_1.5-1.75
# 95          NaN                              GPA_category_1.75-2.0
# 96          NaN                              GPA_category_2.0-2.25
# 97     1.023941                              GPA_category_2.25-2.5
# 98     1.194624                              GPA_category_2.5-2.75
# 99     1.727634                              GPA_category_2.75-3.0
# 100    3.548829                              GPA_category_3.0-3.25
# 101    4.257965                              GPA_category_3.25-3.5
# 102    4.382821                              GPA_category_3.5-3.75
# 103    3.595451                              GPA_category_3.75-4.0
# 104    1.413922                        Class_Rank_Category_100-200
# 105    1.367485                        Class_Rank_Category_200-300
# 106    1.290747                        Class_Rank_Category_300-400
# 107    1.148849                        Class_Rank_Category_400-500
# 108    1.040217                        Class_Rank_Category_500-600
# 109    1.048822                        Class_Rank_Category_600-700
# 110    2.335394                          Top_Percent_Category_5-10
# 111    1.640629                         Top_Percent_Category_10-15
# 112    5.136501                         Top_Percent_Category_15-20
# 113    1.742132                         Top_Percent_Category_20-25
# 114    3.804862                         Top_Percent_Category_25-30
# 115    2.189326                         Top_Percent_Category_30-35
# 116    1.365727                         Top_Percent_Category_35-40
# 117    1.360852                         Top_Percent_Category_40-45
# 118    1.284549                         Top_Percent_Category_45-50
# 119    1.146803                         Top_Percent_Category_50-55
# 120    1.188231                         Top_Percent_Category_55-60
# 121    1.026023                         Top_Percent_Category_60-65
# 122    1.046440                         Top_Percent_Category_65-70
# 123         NaN                         Top_Percent_Category_70-75
# 124    1.091991                         Top_Percent_Category_75-80
# 125    1.050564                         Top_Percent_Category_80-85
# 126         NaN                         Top_Percent_Category_85-90
# 127    1.014806                         Top_Percent_Category_90-95
# 128    1.022237                        Top_Percent_Category_95-100

# %%
# List of columns to drop, it is safe to assume there will not be people applying with below a 2.5 gpa, this
# does not exist in train or test
columns_to_drop = ['GPA_category_0.25-0.5','GPA_category_0.5-0.75','GPA_category_0.75-1.0',
                   'GPA_category_1.0-1.25','GPA_category_1.25-1.5','GPA_category_1.5-1.75',
                   'GPA_category_1.75-2.0','GPA_category_2.0-2.25']

# Drop columns in place
x_train.drop(columns=columns_to_drop, inplace=True)
x_test.drop(columns=columns_to_drop, inplace=True)

# %%
x_train = x_train.drop(columns='Citizenship Status_US Citizen')

# %%
x_test = x_test.drop(columns='Citizenship Status_US Citizen')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['variable'] = x_train.columns
vif[:]
# Out:
#            VIF                                           variable
# 0    17.201859                                             Legacy
# 1    18.052735                                     Sport 1 Rating
# 2     1.649569                          Total Event Participation
# 3     1.486523                             Count of Campus Visits
# 4    39.571840                                     Academic Index
# 5     3.297854                 Intend to Apply for Financial Aid?
# 6     1.551144                       Days_to_Submit_since_Inquiry
# 7     1.430463                 Entry Term (Application)_Fall 2018
# 8     1.012938                           Permanent Country_Cyprus
# 9     1.024949                      Permanent Country_El Salvador
# 10    1.162137                            Permanent Country_India
# 11    1.035244                          Permanent Country_Jamaica
# 12   60.884891                    Permanent Country_United States
# 13    2.805535                                         Race_Asian
# 14    1.538892                     Race_Black or African American
# 15    7.358515                                         Race_White
# 16    1.374520                                 Religion_Christian
# 17    1.295860                                     Religion_Hindu
# 18    1.083277                                  Religion_Lutheran
# 19    1.159144                                 Religion_Methodist
# 20    2.530577                             Religion_Not specified
# 21    1.251140                  Religion_OtherRelgiousAffiliation
# 22    1.142595                       Application Source_Coalition
# 23    5.737683                       Application Source_CommonApp
# 24    1.534449                  Application Source_Select Scholar
# 25    2.080885                       Decision Plan_Early Action I
# 26    1.181426                     Decision Plan_Early Decision I
# 27    1.084325                    Decision Plan_Early Decision II
# 28    1.601231                     Decision Plan_Regular Decision
# 29    1.465875                           Athlete_Athlete, Opt Out
# 30         inf                                Athlete_Non-Athlete
# 31    2.051221                        Sport 1 Sport_Cross Country
# 32    1.168439                               Sport 1 Sport_Diving
# 33    1.250653                                 Sport 1 Sport_Golf
# 34         inf                             Sport 1 Sport_No Sport
# 35    2.025930                               Sport 1 Sport_Soccer
# 36    4.211136                                Sport 1 Sport_Sport
# 37    1.859339                             Sport 1 Sport_Swimming
# 38    1.479841                               Sport 1 Sport_Tennis
# 39    1.999770                                Sport 1 Sport_Track
# 40   50.286346                          Sport 2 Sport_No 2ndSport
# 41   86.923974                          Sport 3 Sport_No 3rdSport
# 42    1.046473  Academic Interest 1_Business - International B...
# 43    1.071562          Academic Interest 1_Business - Management
# 44    1.044702                  Academic Interest 1_Communication
# 45    1.169060            Academic Interest 1_Engineering Science
# 46    1.043448          Academic Interest 1_Environmental Studies
# 47    1.044328                        Academic Interest 1_History
# 48    1.052909                    Academic Interest 1_Mathematics
# 49    1.099335              Academic Interest 1_Political Science
# 50    1.241920                    Academic Interest 1_Pre-Medical
# 51    1.122377                     Academic Interest 1_Psychology
# 52    1.088150                      Academic Interest 1_Undecided
# 53    1.095106  Academic Interest 2_Biochemistry & Molecular B...
# 54    1.184629                       Academic Interest 2_Business
# 55    1.332686                         Academic Interest 2_Others
# 56    1.131746                    Academic Interest 2_Pre-Medical
# 57    1.110466                     Academic Interest 2_Psychology
# 58    1.294547       First_Source Origin First Source Summary_ATH
# 59    1.432452       First_Source Origin First Source Summary_CAP
# 60    5.040658     First_Source Origin First Source Summary_CBINQ
# 61    1.280725        First_Source Origin First Source Summary_CF
# 62    1.894591      First_Source Origin First Source Summary_OAPP
# 63    1.448692  First_Source Origin First Source Summary_Other...
# 64    1.528392      First_Source Origin First Source Summary_SRCH
# 65    1.174103       First_Source Origin First Source Summary_TIF
# 66    1.418913       First_Source Origin First Source Summary_VST
# 67    1.261440     First_Source Origin First Source Summary_WEBTU
# 68    1.105173     First_Source Origin First Source Summary_YUVST
# 69    1.554966                      Permanent Geomarket_Northeast
# 70   18.624027                          Permanent Geomarket_South
# 71    4.226148                           Permanent Geomarket_West
# 72    1.062152              Citizenship Status_Permanent Resident
# 73    1.061602                              Merit Award_Full Ride
# 74    2.973082      Merit Award_International Student Scholarship
# 75    1.510453                   Merit Award_No Merit Scholarship
# 76    1.129381                         ACT Composite Grouped_23.0
# 77    1.126068                         ACT Composite Grouped_24.0
# 78    1.158504                         ACT Composite Grouped_25.0
# 79    1.186787                         ACT Composite Grouped_26.0
# 80    1.261942                         ACT Composite Grouped_27.0
# 81    1.271165                         ACT Composite Grouped_28.0
# 82    1.269581                         ACT Composite Grouped_29.0
# 83    1.331374                         ACT Composite Grouped_33.0
# 84    1.362557                         ACT Composite Grouped_34.0
# 85    1.310761                         ACT Composite Grouped_35.0
# 86    1.102134                         ACT Composite Grouped_36.0
# 87    1.098517                   ACT Composite Grouped_ACTBelow21
# 88    1.023941                              GPA_category_2.25-2.5
# 89    1.185241                              GPA_category_2.5-2.75
# 90    1.717935                              GPA_category_2.75-3.0
# 91    3.516835                              GPA_category_3.0-3.25
# 92    4.235530                              GPA_category_3.25-3.5
# 93    4.369791                              GPA_category_3.5-3.75
# 94    3.594611                              GPA_category_3.75-4.0
# 95    1.413434                        Class_Rank_Category_100-200
# 96    1.367308                        Class_Rank_Category_200-300
# 97    1.290499                        Class_Rank_Category_300-400
# 98    1.148288                        Class_Rank_Category_400-500
# 99    1.040204                        Class_Rank_Category_500-600
# 100   1.048815                        Class_Rank_Category_600-700
# 101   2.335213                          Top_Percent_Category_5-10
# 102   1.640055                         Top_Percent_Category_10-15
# 103   5.120004                         Top_Percent_Category_15-20
# 104   1.740950                         Top_Percent_Category_20-25
# 105   3.797790                         Top_Percent_Category_25-30
# 106   2.189321                         Top_Percent_Category_30-35
# 107   1.365224                         Top_Percent_Category_35-40
# 108   1.360517                         Top_Percent_Category_40-45
# 109   1.284360                         Top_Percent_Category_45-50
# 110   1.145654                         Top_Percent_Category_50-55
# 111   1.187680                         Top_Percent_Category_55-60
# 112   1.025975                         Top_Percent_Category_60-65
# 113   1.046308                         Top_Percent_Category_65-70
# 114        NaN                         Top_Percent_Category_70-75
# 115   1.090818                         Top_Percent_Category_75-80
# 116   1.050549                         Top_Percent_Category_80-85
# 117        NaN                         Top_Percent_Category_85-90
# 118   1.014740                         Top_Percent_Category_90-95
# 119   1.022221                        Top_Percent_Category_95-100

# %%
# List of columns to drop
columns_to_drop = ['Sport 1 Sport_No Sport','Sport 2 Sport_No 2ndSport','Sport 3 Sport_No 3rdSport']

# Drop columns in place
x_train.drop(columns=columns_to_drop, inplace=True)
x_test.drop(columns=columns_to_drop, inplace=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['variable'] = x_train.columns
vif[:]
# Out:
#            VIF                                           variable
# 0    16.950847                                             Legacy
# 1    17.945078                                     Sport 1 Rating
# 2     1.648165                          Total Event Participation
# 3     1.483927                             Count of Campus Visits
# 4    38.897722                                     Academic Index
# 5     3.286561                 Intend to Apply for Financial Aid?
# 6     1.551096                       Days_to_Submit_since_Inquiry
# 7     1.425203                 Entry Term (Application)_Fall 2018
# 8     1.012932                           Permanent Country_Cyprus
# 9     1.024626                      Permanent Country_El Salvador
# 10    1.160939                            Permanent Country_India
# 11    1.034577                          Permanent Country_Jamaica
# 12   58.775272                    Permanent Country_United States
# 13    2.793172                                         Race_Asian
# 14    1.535579                     Race_Black or African American
# 15    7.282093                                         Race_White
# 16    1.372997                                 Religion_Christian
# 17    1.295531                                     Religion_Hindu
# 18    1.082566                                  Religion_Lutheran
# 19    1.158438                                 Religion_Methodist
# 20    2.526828                             Religion_Not specified
# 21    1.250505                  Religion_OtherRelgiousAffiliation
# 22    1.141859                       Application Source_Coalition
# 23    5.683643                       Application Source_CommonApp
# 24    1.532722                  Application Source_Select Scholar
# 25    2.073010                       Decision Plan_Early Action I
# 26    1.180894                     Decision Plan_Early Decision I
# 27    1.083368                    Decision Plan_Early Decision II
# 28    1.598565                     Decision Plan_Regular Decision
# 29    1.464814                           Athlete_Athlete, Opt Out
# 30   54.748375                                Athlete_Non-Athlete
# 31    1.955771                        Sport 1 Sport_Cross Country
# 32    1.135736                               Sport 1 Sport_Diving
# 33    1.206133                                 Sport 1 Sport_Golf
# 34    1.880067                               Sport 1 Sport_Soccer
# 35    3.838888                                Sport 1 Sport_Sport
# 36    1.735025                             Sport 1 Sport_Swimming
# 37    1.394710                               Sport 1 Sport_Tennis
# 38    1.914092                                Sport 1 Sport_Track
# 39    1.046279  Academic Interest 1_Business - International B...
# 40    1.071423          Academic Interest 1_Business - Management
# 41    1.044659                  Academic Interest 1_Communication
# 42    1.168439            Academic Interest 1_Engineering Science
# 43    1.043168          Academic Interest 1_Environmental Studies
# 44    1.044275                        Academic Interest 1_History
# 45    1.051848                    Academic Interest 1_Mathematics
# 46    1.099323              Academic Interest 1_Political Science
# 47    1.241488                    Academic Interest 1_Pre-Medical
# 48    1.122055                     Academic Interest 1_Psychology
# 49    1.088040                      Academic Interest 1_Undecided
# 50    1.094982  Academic Interest 2_Biochemistry & Molecular B...
# 51    1.182287                       Academic Interest 2_Business
# 52    1.330753                         Academic Interest 2_Others
# 53    1.131428                    Academic Interest 2_Pre-Medical
# 54    1.110276                     Academic Interest 2_Psychology
# 55    1.283952       First_Source Origin First Source Summary_ATH
# 56    1.431372       First_Source Origin First Source Summary_CAP
# 57    5.024719     First_Source Origin First Source Summary_CBINQ
# 58    1.276755        First_Source Origin First Source Summary_CF
# 59    1.885142      First_Source Origin First Source Summary_OAPP
# 60    1.446712  First_Source Origin First Source Summary_Other...
# 61    1.525721      First_Source Origin First Source Summary_SRCH
# 62    1.172904       First_Source Origin First Source Summary_TIF
# 63    1.417657       First_Source Origin First Source Summary_VST
# 64    1.260728     First_Source Origin First Source Summary_WEBTU
# 65    1.102910     First_Source Origin First Source Summary_YUVST
# 66    1.554758                      Permanent Geomarket_Northeast
# 67   18.615621                          Permanent Geomarket_South
# 68    4.224429                           Permanent Geomarket_West
# 69    1.062018              Citizenship Status_Permanent Resident
# 70    1.061020                              Merit Award_Full Ride
# 71    2.907009      Merit Award_International Student Scholarship
# 72    1.508954                   Merit Award_No Merit Scholarship
# 73    1.128667                         ACT Composite Grouped_23.0
# 74    1.125046                         ACT Composite Grouped_24.0
# 75    1.158475                         ACT Composite Grouped_25.0
# 76    1.185637                         ACT Composite Grouped_26.0
# 77    1.259898                         ACT Composite Grouped_27.0
# 78    1.271074                         ACT Composite Grouped_28.0
# 79    1.269431                         ACT Composite Grouped_29.0
# 80    1.329104                         ACT Composite Grouped_33.0
# 81    1.358911                         ACT Composite Grouped_34.0
# 82    1.307073                         ACT Composite Grouped_35.0
# 83    1.101554                         ACT Composite Grouped_36.0
# 84    1.097791                   ACT Composite Grouped_ACTBelow21
# 85    1.023909                              GPA_category_2.25-2.5
# 86    1.182110                              GPA_category_2.5-2.75
# 87    1.716252                              GPA_category_2.75-3.0
# 88    3.501894                              GPA_category_3.0-3.25
# 89    4.224705                              GPA_category_3.25-3.5
# 90    4.362484                              GPA_category_3.5-3.75
# 91    3.594285                              GPA_category_3.75-4.0
# 92    1.413294                        Class_Rank_Category_100-200
# 93    1.367124                        Class_Rank_Category_200-300
# 94    1.288686                        Class_Rank_Category_300-400
# 95    1.147494                        Class_Rank_Category_400-500
# 96    1.040189                        Class_Rank_Category_500-600
# 97    1.048788                        Class_Rank_Category_600-700
# 98    2.334918                          Top_Percent_Category_5-10
# 99    1.639770                         Top_Percent_Category_10-15
# 100   5.118143                         Top_Percent_Category_15-20
# 101   1.740598                         Top_Percent_Category_20-25
# 102   3.793462                         Top_Percent_Category_25-30
# 103   2.188462                         Top_Percent_Category_30-35
# 104   1.365096                         Top_Percent_Category_35-40
# 105   1.360200                         Top_Percent_Category_40-45
# 106   1.283676                         Top_Percent_Category_45-50
# 107   1.145199                         Top_Percent_Category_50-55
# 108   1.186936                         Top_Percent_Category_55-60
# 109   1.025935                         Top_Percent_Category_60-65
# 110   1.046267                         Top_Percent_Category_65-70
# 111        NaN                         Top_Percent_Category_70-75
# 112   1.085686                         Top_Percent_Category_75-80
# 113   1.050307                         Top_Percent_Category_80-85
# 114        NaN                         Top_Percent_Category_85-90
# 115   1.014704                         Top_Percent_Category_90-95
# 116   1.022172                        Top_Percent_Category_95-100

# %%
with open('x_train.pkl', 'wb') as f:
    pk.dump(x_train, f)

# %%
with open('x_test.pkl', 'wb') as f:
    pk.dump(x_test, f)

# %%
# List of columns to drop
columns_to_drop = ['Athlete_Non-Athlete','Permanent Country_United States','Academic Index']

# Drop columns in place
x_train.drop(columns=columns_to_drop, inplace=True)
x_test.drop(columns=columns_to_drop, inplace=True)

# %%
x_test.head()
# Out:
#        Legacy  Sport 1 Rating  Total Event Participation  \
# ID
# 10001       2               2                          1
# 10002       2               2                          2
# 10003       2               2                          0
# 10004       2               2                          0
# 10005       2               2                          0
#
#        Count of Campus Visits  Intend to Apply for Financial Aid?  \
# ID
# 10001                       0                                 1.0
# 10002                       1                                 0.0
# 10003                       0                                 1.0
# 10004                       0                                 1.0
# 10005                       1                                 0.0
#
#        Days_to_Submit_since_Inquiry  Entry Term (Application)_Fall 2018  \
# ID
# 10001                         -30.0                                   0
# 10002                          -9.0                                   0
# 10003                           0.0                                   0
# 10004                        6096.0                                   0
# 10005                           0.0                                   0
#
#        Permanent Country_Cyprus  Permanent Country_El Salvador  \
# ID
# 10001                         0                              0
# 10002                         0                              0
# 10003                         0                              0
# 10004                         0                              0
# 10005                         0                              0
#
#        Permanent Country_India  Permanent Country_Jamaica  Race_Asian  \
# ID
# 10001                        0                          0           0
# 10002                        0                          0           0
# 10003                        0                          0           0
# 10004                        0                          0           0
# 10005                        0                          0           0
#
#        Race_Black or African American  Race_White  Religion_Christian  \
# ID
# 10001                               0           1                   1
# 10002                               0           1                   0
# 10003                               0           1                   0
# 10004                               0           0                   0
# 10005                               0           1                   0
#
#        Religion_Hindu  Religion_Lutheran  Religion_Methodist  \
# ID
# 10001               0                  0                   0
# 10002               0                  0                   1
# 10003               0                  0                   0
# 10004               0                  0                   0
# 10005               0                  0                   0
#
#        Religion_Not specified  Religion_OtherRelgiousAffiliation  \
# ID
# 10001                       0                                  0
# 10002                       0                                  0
# 10003                       0                                  1
# 10004                       1                                  0
# 10005                       1                                  0
#
#        Application Source_Coalition  Application Source_CommonApp  \
# ID
# 10001                             0                             0
# 10002                             0                             1
# 10003                             0                             1
# 10004                             0                             1
# 10005                             0                             1
#
#        Application Source_Select Scholar  Decision Plan_Early Action I  \
# ID
# 10001                                  0                             1
# 10002                                  0                             0
# 10003                                  0                             0
# 10004                                  0                             0
# 10005                                  0                             0
#
#        Decision Plan_Early Decision I  Decision Plan_Early Decision II  \
# ID
# 10001                               0                                0
# 10002                               0                                0
# 10003                               0                                0
# 10004                               0                                0
# 10005                               0                                0
#
#        Decision Plan_Regular Decision  Athlete_Athlete, Opt Out  \
# ID
# 10001                               0                         0
# 10002                               0                         0
# 10003                               0                         0
# 10004                               1                         0
# 10005                               0                         0
#
#        Sport 1 Sport_Cross Country  Sport 1 Sport_Diving  Sport 1 Sport_Golf  \
# ID
# 10001                            0                     0                   0
# 10002                            0                     0                   0
# 10003                            0                     0                   0
# 10004                            0                     0                   0
# 10005                            0                     0                   0
#
#        Sport 1 Sport_Soccer  Sport 1 Sport_Sport  Sport 1 Sport_Swimming  \
# ID
# 10001                     0                    0                       0
# 10002                     0                    0                       0
# 10003                     0                    0                       0
# 10004                     0                    0                       0
# 10005                     0                    0                       0
#
#        Sport 1 Sport_Tennis  Sport 1 Sport_Track  \
# ID
# 10001                     0                    0
# 10002                     0                    0
# 10003                     0                    0
# 10004                     0                    0
# 10005                     0                    0
#
#        Academic Interest 1_Business - International Business  \
# ID
# 10001                                                  0
# 10002                                                  0
# 10003                                                  0
# 10004                                                  0
# 10005                                                  0
#
#        Academic Interest 1_Business - Management  \
# ID
# 10001                                          0
# 10002                                          0
# 10003                                          0
# 10004                                          0
# 10005                                          0
#
#        Academic Interest 1_Communication  \
# ID
# 10001                                  0
# 10002                                  0
# 10003                                  0
# 10004                                  0
# 10005                                  0
#
#        Academic Interest 1_Engineering Science  \
# ID
# 10001                                        1
# 10002                                        0
# 10003                                        0
# 10004                                        0
# 10005                                        1
#
#        Academic Interest 1_Environmental Studies  Academic Interest 1_History  \
# ID
# 10001                                          0                            0
# 10002                                          0                            0
# 10003                                          0                            0
# 10004                                          0                            0
# 10005                                          0                            0
#
#        Academic Interest 1_Mathematics  Academic Interest 1_Political Science  \
# ID
# 10001                                0                                      0
# 10002                                0                                      0
# 10003                                0                                      0
# 10004                                0                                      0
# 10005                                0                                      0
#
#        Academic Interest 1_Pre-Medical  Academic Interest 1_Psychology  \
# ID
# 10001                                0                               0
# 10002                                0                               0
# 10003                                0                               1
# 10004                                1                               0
# 10005                                0                               0
#
#        Academic Interest 1_Undecided  \
# ID
# 10001                              0
# 10002                              0
# 10003                              0
# 10004                              0
# 10005                              0
#
#        Academic Interest 2_Biochemistry & Molecular Biology  \
# ID
# 10001                                                  0
# 10002                                                  0
# 10003                                                  0
# 10004                                                  0
# 10005                                                  0
#
#        Academic Interest 2_Business  Academic Interest 2_Others  \
# ID
# 10001                             0                           0
# 10002                             0                           1
# 10003                             0                           0
# 10004                             0                           1
# 10005                             0                           1
#
#        Academic Interest 2_Pre-Medical  Academic Interest 2_Psychology  \
# ID
# 10001                                0                               0
# 10002                                0                               0
# 10003                                0                               0
# 10004                                0                               0
# 10005                                0                               0
#
#        First_Source Origin First Source Summary_ATH  \
# ID
# 10001                                             0
# 10002                                             0
# 10003                                             0
# 10004                                             0
# 10005                                             0
#
#        First_Source Origin First Source Summary_CAP  \
# ID
# 10001                                             0
# 10002                                             0
# 10003                                             0
# 10004                                             1
# 10005                                             0
#
#        First_Source Origin First Source Summary_CBINQ  \
# ID
# 10001                                               1
# 10002                                               1
# 10003                                               0
# 10004                                               0
# 10005                                               0
#
#        First_Source Origin First Source Summary_CF  \
# ID
# 10001                                            0
# 10002                                            0
# 10003                                            0
# 10004                                            0
# 10005                                            0
#
#        First_Source Origin First Source Summary_OAPP  \
# ID
# 10001                                              0
# 10002                                              0
# 10003                                              0
# 10004                                              0
# 10005                                              0
#
#        First_Source Origin First Source Summary_Other Sources  \
# ID
# 10001                                                  0
# 10002                                                  0
# 10003                                                  0
# 10004                                                  0
# 10005                                                  0
#
#        First_Source Origin First Source Summary_SRCH  \
# ID
# 10001                                              0
# 10002                                              0
# 10003                                              0
# 10004                                              0
# 10005                                              0
#
#        First_Source Origin First Source Summary_TIF  \
# ID
# 10001                                             0
# 10002                                             0
# 10003                                             0
# 10004                                             0
# 10005                                             0
#
#        First_Source Origin First Source Summary_VST  \
# ID
# 10001                                             0
# 10002                                             0
# 10003                                             0
# 10004                                             0
# 10005                                             1
#
#        First_Source Origin First Source Summary_WEBTU  \
# ID
# 10001                                               0
# 10002                                               0
# 10003                                               0
# 10004                                               0
# 10005                                               0
#
#        First_Source Origin First Source Summary_YUVST  \
# ID
# 10001                                               0
# 10002                                               0
# 10003                                               0
# 10004                                               0
# 10005                                               0
#
#        Permanent Geomarket_Northeast  Permanent Geomarket_South  \
# ID
# 10001                              0                          1
# 10002                              0                          1
# 10003                              0                          1
# 10004                              0                          1
# 10005                              0                          1
#
#        Permanent Geomarket_West  Citizenship Status_Permanent Resident  \
# ID
# 10001                         0                                      0
# 10002                         0                                      0
# 10003                         0                                      0
# 10004                         0                                      0
# 10005                         0                                      0
#
#        Merit Award_Full Ride  Merit Award_International Student Scholarship  \
# ID
# 10001                      0                                              0
# 10002                      0                                              0
# 10003                      0                                              0
# 10004                      0                                              0
# 10005                      0                                              0
#
#        Merit Award_No Merit Scholarship  ACT Composite Grouped_23.0  \
# ID
# 10001                                 0                           0
# 10002                                 0                           0
# 10003                                 0                           0
# 10004                                 0                           0
# 10005                                 0                           0
#
#        ACT Composite Grouped_24.0  ACT Composite Grouped_25.0  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        ACT Composite Grouped_26.0  ACT Composite Grouped_27.0  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           1
# 10005                           0                           0
#
#        ACT Composite Grouped_28.0  ACT Composite Grouped_29.0  \
# ID
# 10001                           1                           0
# 10002                           0                           0
# 10003                           0                           1
# 10004                           0                           0
# 10005                           0                           0
#
#        ACT Composite Grouped_33.0  ACT Composite Grouped_34.0  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           1
#
#        ACT Composite Grouped_35.0  ACT Composite Grouped_36.0  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        ACT Composite Grouped_ACTBelow21  GPA_category_2.25-2.5  \
# ID
# 10001                                 0                      0
# 10002                                 0                      0
# 10003                                 0                      0
# 10004                                 0                      0
# 10005                                 0                      0
#
#        GPA_category_2.5-2.75  GPA_category_2.75-3.0  GPA_category_3.0-3.25  \
# ID
# 10001                      0                      0                      0
# 10002                      0                      0                      0
# 10003                      0                      0                      0
# 10004                      0                      0                      0
# 10005                      0                      0                      0
#
#        GPA_category_3.25-3.5  GPA_category_3.5-3.75  GPA_category_3.75-4.0  \
# ID
# 10001                      1                      0                      0
# 10002                      0                      0                      1
# 10003                      0                      1                      0
# 10004                      0                      0                      0
# 10005                      0                      1                      0
#
#        Class_Rank_Category_100-200  Class_Rank_Category_200-300  \
# ID
# 10001                            0                            0
# 10002                            0                            0
# 10003                            0                            0
# 10004                            0                            0
# 10005                            0                            0
#
#        Class_Rank_Category_300-400  Class_Rank_Category_400-500  \
# ID
# 10001                            0                            0
# 10002                            0                            0
# 10003                            0                            0
# 10004                            0                            0
# 10005                            0                            0
#
#        Class_Rank_Category_500-600  Class_Rank_Category_600-700  \
# ID
# 10001                            0                            0
# 10002                            0                            0
# 10003                            0                            0
# 10004                            0                            0
# 10005                            0                            0
#
#        Top_Percent_Category_5-10  Top_Percent_Category_10-15  \
# ID
# 10001                          0                           0
# 10002                          1                           0
# 10003                          0                           0
# 10004                          0                           0
# 10005                          0                           1
#
#        Top_Percent_Category_15-20  Top_Percent_Category_20-25  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           1                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_25-30  Top_Percent_Category_30-35  \
# ID
# 10001                           1                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_35-40  Top_Percent_Category_40-45  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_45-50  Top_Percent_Category_50-55  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_55-60  Top_Percent_Category_60-65  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_65-70  Top_Percent_Category_70-75  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_75-80  Top_Percent_Category_80-85  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_85-90  Top_Percent_Category_90-95  \
# ID
# 10001                           0                           0
# 10002                           0                           0
# 10003                           0                           0
# 10004                           0                           0
# 10005                           0                           0
#
#        Top_Percent_Category_95-100
# ID
# 10001                            0
# 10002                            0
# 10003                            0
# 10004                            0
# 10005                            0

# %%
# My logisitc model was not running as a result of these categories not having any train values so I had to 
# remove them and identify them through this loop
constant_cols = [col for col in x_train.columns if x_train[col].nunique() == 1]
print(f"Constant columns: {constant_cols}")
x_train = x_train.drop(columns=constant_cols)
x_test = x_test.drop(columns=constant_cols)
# Out:
# Constant columns: ['Top_Percent_Category_70-75', 'Top_Percent_Category_85-90']

# %%
# Define the Logistis model 

model_logistic = sm.Logit(endog = y_train, exog = sm.add_constant(x_train)).fit()

model_logistic.summary() # output model summary
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.348539
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Decision   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9887
# Method:                           MLE   Df Model:                          112
# Date:                Sat, 14 Dec 2024   Pseudo R-squ.:                  0.3372
# Time:                        20:47:41   Log-Likelihood:                -3485.4
# converged:                      False   LL-Null:                       -5258.9
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                     -1.6565      0.278     -5.949      0.000      -2.202      -1.111
# Legacy                                                    -0.4932      0.057     -8.581      0.000      -0.606      -0.381
# Sport 1 Rating                                            -0.1025      0.065     -1.584      0.113      -0.229       0.024
# Total Event Participation                                  1.6454      0.056     29.599      0.000       1.536       1.754
# Count of Campus Visits                                     0.7539      0.041     18.177      0.000       0.673       0.835
# Intend to Apply for Financial Aid?                         0.1664      0.069      2.427      0.015       0.032       0.301
# Days_to_Submit_since_Inquiry                           -4.589e-06   1.05e-05     -0.436      0.663   -2.52e-05    1.61e-05
# Entry Term (Application)_Fall 2018                         0.0260      0.082      0.315      0.752      -0.135       0.187
# Permanent Country_Cyprus                                   2.2716      1.241      1.830      0.067      -0.161       4.704
# Permanent Country_El Salvador                            -16.2950   2514.720     -0.006      0.995   -4945.057    4912.466
# Permanent Country_India                                   -0.4508      0.527     -0.856      0.392      -1.484       0.582
# Permanent Country_Jamaica                                -15.3196   2140.491     -0.007      0.994   -4210.604    4179.965
# Race_Asian                                                -0.1298      0.134     -0.970      0.332      -0.392       0.132
# Race_Black or African American                            -0.4916      0.186     -2.647      0.008      -0.856      -0.128
# Race_White                                                 0.0413      0.103      0.402      0.688      -0.160       0.243
# Religion_Christian                                        -0.0147      0.108     -0.136      0.892      -0.226       0.197
# Religion_Hindu                                            -0.1525      0.266     -0.574      0.566      -0.673       0.368
# Religion_Lutheran                                          0.2110      0.221      0.956      0.339      -0.222       0.644
# Religion_Methodist                                        -0.0932      0.152     -0.615      0.539      -0.390       0.204
# Religion_Not specified                                     0.1597      0.075      2.134      0.033       0.013       0.306
# Religion_OtherRelgiousAffiliation                         -0.1688      0.131     -1.286      0.198      -0.426       0.088
# Application Source_Coalition                              -0.5151      0.286     -1.804      0.071      -1.075       0.045
# Application Source_CommonApp                               0.0618      0.082      0.751      0.453      -0.099       0.223
# Application Source_Select Scholar                         -0.1809      0.172     -1.050      0.294      -0.519       0.157
# Decision Plan_Early Action I                              -0.2494      0.074     -3.360      0.001      -0.395      -0.104
# Decision Plan_Early Decision I                             3.5215      0.298     11.815      0.000       2.937       4.106
# Decision Plan_Early Decision II                            4.0797      0.529      7.714      0.000       3.043       5.116
# Decision Plan_Regular Decision                             0.3328      0.086      3.855      0.000       0.164       0.502
# Athlete_Athlete, Opt Out                                 -21.9639   1742.139     -0.013      0.990   -3436.494    3392.566
# Sport 1 Sport_Cross Country                                1.3133      0.251      5.223      0.000       0.820       1.806
# Sport 1 Sport_Diving                                       2.3044      0.676      3.410      0.001       0.980       3.629
# Sport 1 Sport_Golf                                         2.3980      0.633      3.789      0.000       1.158       3.638
# Sport 1 Sport_Soccer                                       2.0240      0.265      7.639      0.000       1.505       2.543
# Sport 1 Sport_Sport                                        1.5043      0.152      9.914      0.000       1.207       1.802
# Sport 1 Sport_Swimming                                     1.4783      0.284      5.210      0.000       0.922       2.034
# Sport 1 Sport_Tennis                                       1.6293      0.392      4.157      0.000       0.861       2.398
# Sport 1 Sport_Track                                        1.1669      0.242      4.821      0.000       0.693       1.641
# Academic Interest 1_Business - International Business     -0.5359      0.289     -1.853      0.064      -1.103       0.031
# Academic Interest 1_Business - Management                  0.0145      0.211      0.069      0.945      -0.398       0.427
# Academic Interest 1_Communication                         -0.0696      0.261     -0.267      0.790      -0.582       0.442
# Academic Interest 1_Engineering Science                   -0.3364      0.119     -2.824      0.005      -0.570      -0.103
# Academic Interest 1_Environmental Studies                  0.2400      0.223      1.075      0.283      -0.198       0.678
# Academic Interest 1_History                               -0.5699      0.289     -1.975      0.048      -1.136      -0.004
# Academic Interest 1_Mathematics                            0.3942      0.216      1.822      0.068      -0.030       0.818
# Academic Interest 1_Political Science                     -0.1365      0.160     -0.855      0.392      -0.449       0.176
# Academic Interest 1_Pre-Medical                           -0.0851      0.108     -0.787      0.432      -0.297       0.127
# Academic Interest 1_Psychology                             0.2995      0.129      2.318      0.020       0.046       0.553
# Academic Interest 1_Undecided                              0.1476      0.145      1.021      0.307      -0.136       0.431
# Academic Interest 2_Biochemistry & Molecular Biology      -0.3403      0.175     -1.945      0.052      -0.683       0.003
# Academic Interest 2_Business                              -0.0765      0.121     -0.633      0.527      -0.313       0.160
# Academic Interest 2_Others                                -0.0059      0.083     -0.071      0.944      -0.169       0.157
# Academic Interest 2_Pre-Medical                           -0.1905      0.144     -1.320      0.187      -0.473       0.092
# Academic Interest 2_Psychology                             0.1581      0.139      1.141      0.254      -0.113       0.430
# First_Source Origin First Source Summary_ATH              -0.5532      0.287     -1.928      0.054      -1.116       0.009
# First_Source Origin First Source Summary_CAP              -0.5721      0.241     -2.372      0.018      -1.045      -0.099
# First_Source Origin First Source Summary_CBINQ             0.0652      0.101      0.646      0.518      -0.132       0.263
# First_Source Origin First Source Summary_CF               -0.0785      0.175     -0.448      0.654      -0.422       0.265
# First_Source Origin First Source Summary_OAPP             -0.1418      0.142     -0.999      0.318      -0.420       0.136
# First_Source Origin First Source Summary_Other Sources     0.0517      0.146      0.354      0.724      -0.235       0.338
# First_Source Origin First Source Summary_SRCH             -0.0147      0.179     -0.082      0.935      -0.365       0.335
# First_Source Origin First Source Summary_TIF              -0.6795      0.262     -2.591      0.010      -1.194      -0.165
# First_Source Origin First Source Summary_VST               0.0517      0.157      0.329      0.742      -0.256       0.360
# First_Source Origin First Source Summary_WEBTU             0.0828      0.185      0.447      0.655      -0.280       0.446
# First_Source Origin First Source Summary_YUVST             0.1328      0.279      0.475      0.635      -0.415       0.680
# Permanent Geomarket_Northeast                             -0.2422      0.252     -0.960      0.337      -0.736       0.252
# Permanent Geomarket_South                                 -0.2446      0.134     -1.821      0.069      -0.508       0.019
# Permanent Geomarket_West                                  -0.5499      0.157     -3.495      0.000      -0.858      -0.242
# Citizenship Status_Permanent Resident                     -0.8176      0.282     -2.902      0.004      -1.370      -0.266
# Merit Award_Full Ride                                      1.3627      0.242      5.621      0.000       0.888       1.838
# Merit Award_International Student Scholarship              0.4663      0.190      2.459      0.014       0.095       0.838
# Merit Award_No Merit Scholarship                           0.0438      0.352      0.124      0.901      -0.647       0.734
# ACT Composite Grouped_23.0                                 0.1411      0.347      0.407      0.684      -0.539       0.821
# ACT Composite Grouped_24.0                                 0.3249      0.221      1.473      0.141      -0.107       0.757
# ACT Composite Grouped_25.0                                 0.3195      0.181      1.769      0.077      -0.034       0.673
# ACT Composite Grouped_26.0                                 0.2396      0.157      1.525      0.127      -0.068       0.548
# ACT Composite Grouped_27.0                                -0.0342      0.128     -0.266      0.790      -0.286       0.217
# ACT Composite Grouped_28.0                                 0.1418      0.114      1.240      0.215      -0.082       0.366
# ACT Composite Grouped_29.0                                -0.0893      0.114     -0.787      0.432      -0.312       0.133
# ACT Composite Grouped_33.0                                -0.3725      0.114     -3.273      0.001      -0.596      -0.149
# ACT Composite Grouped_34.0                                -0.8024      0.137     -5.837      0.000      -1.072      -0.533
# ACT Composite Grouped_35.0                                -0.8670      0.160     -5.431      0.000      -1.180      -0.554
# ACT Composite Grouped_36.0                                -0.9330      0.278     -3.357      0.001      -1.478      -0.388
# ACT Composite Grouped_ACTBelow21                           0.6168      0.689      0.895      0.371      -0.734       1.967
# GPA_category_2.25-2.5                                     16.0084    1.5e+04      0.001      0.999   -2.93e+04    2.93e+04
# GPA_category_2.5-2.75                                      1.0593      0.644      1.645      0.100      -0.203       2.321
# GPA_category_2.75-3.0                                      0.5032      0.287      1.752      0.080      -0.060       1.066
# GPA_category_3.0-3.25                                      0.3287      0.176      1.870      0.061      -0.016       0.673
# GPA_category_3.25-3.5                                      0.3085      0.144      2.149      0.032       0.027       0.590
# GPA_category_3.5-3.75                                      0.2254      0.124      1.811      0.070      -0.018       0.469
# GPA_category_3.75-4.0                                      0.0597      0.099      0.602      0.547      -0.135       0.254
# Class_Rank_Category_100-200                                0.2748      0.128      2.153      0.031       0.025       0.525
# Class_Rank_Category_200-300                               -0.2999      0.245     -1.226      0.220      -0.779       0.180
# Class_Rank_Category_300-400                                0.2574      0.356      0.723      0.470      -0.440       0.955
# Class_Rank_Category_400-500                               -0.1921      0.861     -0.223      0.823      -1.880       1.495
# Class_Rank_Category_500-600                                1.6947      1.519      1.116      0.265      -1.283       4.672
# Class_Rank_Category_600-700                              -20.6963   2.88e+04     -0.001      0.999   -5.65e+04    5.64e+04
# Top_Percent_Category_5-10                                  0.0322      0.104      0.310      0.756      -0.171       0.235
# Top_Percent_Category_10-15                                 0.4722      0.140      3.364      0.001       0.197       0.747
# Top_Percent_Category_15-20                                 0.2652      0.124      2.145      0.032       0.023       0.508
# Top_Percent_Category_20-25                                 0.6003      0.200      3.001      0.003       0.208       0.992
# Top_Percent_Category_25-30                                 0.1169      0.165      0.707      0.480      -0.207       0.441
# Top_Percent_Category_30-35                                 0.2433      0.232      1.049      0.294      -0.211       0.698
# Top_Percent_Category_35-40                                 0.5302      0.356      1.487      0.137      -0.169       1.229
# Top_Percent_Category_40-45                                 0.8589      0.339      2.536      0.011       0.195       1.523
# Top_Percent_Category_45-50                                 1.1449      0.439      2.606      0.009       0.284       2.006
# Top_Percent_Category_50-55                                 0.1061      0.660      0.161      0.872      -1.188       1.400
# Top_Percent_Category_55-60                                 1.3918      0.677      2.055      0.040       0.064       2.719
# Top_Percent_Category_60-65                                 2.1340      1.497      1.426      0.154      -0.800       5.068
# Top_Percent_Category_65-70                                 0.6166      1.090      0.566      0.572      -1.519       2.753
# Top_Percent_Category_75-80                                19.3406    1.5e+04      0.001      0.999   -2.93e+04    2.94e+04
# Top_Percent_Category_80-85                                16.1871    1.5e+04      0.001      0.999   -2.93e+04    2.93e+04
# Top_Percent_Category_90-95                               -18.7269    1.5e+04     -0.001      0.999   -2.94e+04    2.93e+04
# Top_Percent_Category_95-100                              -17.6449    1.5e+04     -0.001      0.999   -2.94e+04    2.93e+04
# ==========================================================================================================================
# """

# %%
# Predictions using x_test

y_test_pred_prob = model_logistic.predict(sm.add_constant(x_test))

# %%
y_train_pred_prob = model_logistic.predict(sm.add_constant(x_train))

# %%
# Selecting the optimal cut-off probability
# The cut-off probability begins at 0.1, increments by 0.01, and ends at 0.9.
Kappa_test_logis = []
cut_off_prob = []

for prob in np.arange(0.1, 0.91, 0.01):
    cut_off_prob.append(round(prob, 2))
    y_test_pred_class = np.where(y_test_pred_prob >= prob, 1, 0)
    Kappa = cohen_kappa_score(y1 = y_test_pred_class, y2 = y_test) 
    Kappa_test_logis.append(Kappa)
    
print(Kappa_test_logis.index(max(Kappa_test_logis))) # Get the index of the largest test Kappa
print(cut_off_prob[Kappa_test_logis.index(max(Kappa_test_logis))]) # Get the corresponding cut-off probability
print(max(Kappa_test_logis)) # Get the corresponding test Kappa

# Conclusion: the optimal cut-off probability is 0.31, giving us the best test Kappa of 0.47699083049308555.
# Out:
# 17
# 0.27
# 0.5028468539607458

# %%
y_test_pred_class = np.where(y_test_pred_prob >= 0.27, 1, 0)
print(y_test_pred_class)
# Out:
# [0 1 0 ... 1 0 1]

# %%
y_train_pred_class = np.where(y_train_pred_prob >= 0.27, 1, 0)
print(y_test_pred_class)
# Out:
# [0 1 0 ... 1 0 1]

# %%
Kappa_train_logis = cohen_kappa_score(y1 = y_train_pred_class, y2 = y_train) 
print(Kappa_train_logis)
# Out:
# 0.5284355534384654

# %%
Kappa_test_logis = cohen_kappa_score(y1 = y_test_pred_class, y2 = y_test) 
print(Kappa_test_logis)
# Out:
# 0.5028468539607458

# %%
# Training Kappa: 0.528
# Test Kappa: 0.503

# %% [markdown]
# ## KNN Model

# %%
x_train = pd.read_pickle("x_train.pkl")
x_test = pd.read_pickle("x_test.pkl")

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
x_train = scaler.fit_transform(x_train) # fit to data, then transform it.
x_test = scaler.fit_transform(x_test) 
print(np.mean(x_train), np.std(x_train)) 
print(np.mean(x_test), np.std(x_test))
# Out:
# 4.979872165156258e-18 0.9914161502144208
# 3.0819694187832462e-18 0.9827573280377847

# %%
# Choosing the Optimal K value
from sklearn.neighbors import KNeighborsClassifier
# Splitting training data into sub-training and sub-test sets using a 75-25 split.
x_subtrain, x_subtest, y_subtrain, y_subtest = train_test_split(x_train, y_train, train_size = 0.75, test_size = 0.25,
                                                       random_state = 123, stratify = y_train)

# Defining the Loop
Kappa_subtest_knn = []
k = [] 
for i in np.arange(1,101,1): # K is from 1 to 100
    k.append(i)
    model_knn = KNeighborsClassifier(n_neighbors = i) 
    model_knn.fit(x_subtrain,y_subtrain)
    y_subtest_pred_class = model_knn.predict(x_subtest)
    Kappa = cohen_kappa_score(y1 = y_subtest_pred_class, y2 = y_subtest) 
    Kappa_subtest_knn.append(Kappa)
    
# Output the best K value    
print(k[Kappa_subtest_knn.index(max(Kappa_subtest_knn))]) #Get the corresponding K value
print((max(Kappa_subtest_knn))) #Get the corresponding test Kappa
#Conclusion: the optimal K is 5, giving us the best subtest Kappa of 0.27822712671345007.
# Out:
# 1
# 0.25526566748343604

# %%
# 2.4 Use the best K value to build a knn model

# Define and fit the knn model
model_4nn = KNeighborsClassifier(n_neighbors = 1).fit(x_train, y_train)

# Classification performance for training data
y_train_pred_class = model_4nn.predict(x_train)
Kappa_train_4nn = cohen_kappa_score(y1 = y_train_pred_class, y2 = y_train)
print(Kappa_train_4nn) # =0.8892

# Classification performance for test data
y_test_pred_class = model_4nn.predict(x_test)
Kappa_test_4nn = cohen_kappa_score(y1 = y_test_pred_class, y2 = y_test)
print(Kappa_test_4nn) # =0.7643
# Out:
# 0.9991234389616656
# 0.23908810969537264

# %%
# Training Kappa: 0.999
# Test Kappa: 0.239

# %% [markdown]
# ## Simple Classification Tree

# %%
# Simple Tree
simple_class_tree = DecisionTreeClassifier(criterion='gini',
                                    max_features = x_train.shape[1],
                                    random_state = 123,
                                    min_samples_split = 2, 
                                    min_samples_leaf = 1,
                                    max_depth = None,
                                    ccp_alpha = 0).fit(x_train, y_train)

# %%
# 3.4 Training Kappa
simple_class_tree_pred_train = simple_class_tree.predict(x_train)
print(simple_class_tree_pred_train)
Kappa_train_simple_class_tree = cohen_kappa_score(y1 = simple_class_tree_pred_train, y2 = y_train)
print(Kappa_train_simple_class_tree)
# Out:
# [1 0 1 ... 0 0 0]
# 0.9991231511935198

# %%
# 3.5 Test Kappa
simple_class_tree_pred_test = simple_class_tree.predict(x_test)
print(simple_class_tree_pred_test)
Kappa_test_simple_class_tree = cohen_kappa_score(y1 = simple_class_tree_pred_test, y2 = y_test)
print(Kappa_test_simple_class_tree)
# Out:
# [0 0 0 ... 0 0 1]
# 0.3723508689147814

# %%
# Training Kappa: 0.999
# Test Kappa: 0.372

# %% [markdown]
# #  Pruned Decision Tree

# %%
# Define cross-validation data splitting strategy
kf_simple_class_tree = KFold(n_splits = 10, shuffle = True, random_state = 42)

# %%
# Define a search grid for the tuning parameter

unpruned_tree_leaf_nodes = simple_class_tree.tree_.n_leaves # The total number of leaves in the fully grown tree
print(unpruned_tree_leaf_nodes)
# Out:
# 1676

# %%
param_grid_class_tree = {'max_leaf_nodes': list(range(2, 1676, 150))}

# %%
# Cross-validation for each max_leaf_nodes value in the grid
cv_class_tree_pruning = GridSearchCV(estimator = simple_class_tree_estimator,
                              param_grid = param_grid_class_tree, 
                              scoring = 'balanced_accuracy',
                              cv = kf_simple_class_tree) 
cv_class_tree_pruning.fit(x_train, y_train)

print(cv_class_tree_pruning.best_params_, cv_class_tree_pruning.best_score_)
# Out:
# {'max_leaf_nodes': 152} 0.6988789942872344

# %%
# Fit the pruned classification tree
simple_class_tree_pruned = DecisionTreeClassifier(criterion = 'gini',  
                                    min_samples_split = 2, 
                                    min_samples_leaf = 1,
                                    max_depth = None,
                                    max_leaf_nodes = 152,
                                    max_features = x_train.shape[1],
                                    random_state=123,
                                    ccp_alpha = 0.0).fit(x_train, y_train)

# %%
# Training Kappa
simple_class_tree_pruned_pred_train = simple_class_tree_pruned.predict(x_train)
print(simple_class_tree_pruned_pred_train)
Kappa_train_simple_class_tree_pruned = cohen_kappa_score(y1 = simple_class_tree_pruned_pred_train, y2 = y_train)
print(Kappa_train_simple_class_tree_pruned)
# Out:
# [1 0 1 ... 0 0 0]
# 0.6080964341334703

# %%
# Test Kappa
simple_class_tree_pruned_pred_test = simple_class_tree_pruned.predict(x_test)
print(simple_class_tree_pruned_pred_test)
Kappa_test_simple_class_tree_pruned = cohen_kappa_score(y1 = simple_class_tree_pruned_pred_test, y2 = y_test)
print(Kappa_test_simple_class_tree_pruned)
# Out:
# [0 1 0 ... 1 0 1]
# 0.4571679199540757

# %%
# Training Kappa: 0.608
# Test Kappa: 0.457

# %% [markdown]
# #  Random Forest

# %%
# Defining cross-validation data splitting strategy
kf_rf_class_tree = KFold(n_splits = 10, shuffle = True, random_state = 42)

# %%
# Defining the RF estimator
import math

rf_class_tree_estimator = RandomForestClassifier(n_estimators=500, 
                                        criterion='gini', 
                                        max_depth = None,
                                        min_samples_split = 2,
                                        min_samples_leaf = 1, 
                                        max_leaf_nodes = None,
                                        max_features= x_train.shape[1], 
                                        bootstrap=True,
                                        max_samples = math.ceil(x_train.shape[0] * 0.9) -1,
                                        random_state = 42)

# %%
unpruned_tree_leaf_nodes = simple_class_tree.tree_.n_leaves # The total number of leaves in the fully grown tree
print(unpruned_tree_leaf_nodes)
# Out:
# 1676

# %%
# Defining a search grid for the tuning parameters
param_grid_rf_class_tree = {'max_leaf_nodes': list(range(2, 1676,250)),
                            'max_features': list(range(1, x_train.shape[1],5))}

# %%
# Excecuting cross-validation for each combination in the grid
cv_rf_class_tree = GridSearchCV(estimator = rf_class_tree_estimator,
                              param_grid = param_grid_rf_class_tree, 
                              scoring = 'balanced_accuracy',
                              cv = kf_rf_class_tree,
                              n_jobs = -1) 
cv_rf_class_tree.fit(x_train, y_train)

# Outputting the best max_leaf_nodes and the corresponding cross-validation score
print(cv_rf_class_tree.best_params_, cv_rf_class_tree.best_score_)
# Out:
# {'max_features': 41, 'max_leaf_nodes': 752} 0.7117356215565324

# %%
# Fitting the optimal RF
rf_class_tree_best = RandomForestClassifier(n_estimators=500, 
                                        criterion='gini', 
                                        max_depth = None,
                                        min_samples_split = 2,
                                        min_samples_leaf = 1, 
                                        max_leaf_nodes = 752,
                                        max_features= 41, 
                                        bootstrap=True,
                                        max_samples = x_train.shape[0],
                                        random_state = 42).fit(x_train, y_train)

# %%
# Training Kappa
rf_class_tree_best_pred_train = rf_class_tree_best.predict(x_train)
Kappa_train_rf_class_tree_best = cohen_kappa_score(y1 = rf_class_tree_best_pred_train, y2 = y_train)
print(Kappa_train_rf_class_tree_best)
# Out:
# 0.8889640095342903

# %%
# Test Kappa
rf_class_tree_best_pred_test = rf_class_tree_best.predict(x_test)
Kappa_test_rf_class_tree_best = cohen_kappa_score(y1 = rf_class_tree_best_pred_test, y2 = y_test)
print(Kappa_test_rf_class_tree_best)
# Out:
# 0.4796968398888146

# %%
# Training Kappa: 0.889
# Test Kappa: 0.

# %% [markdown]
# # Boosting

# %%
# Perform K-fold cross-validation to select the best combination of n_estimators and max_leaf_nodes

# Define the estimator
Tree_class_boosting_estimator = GradientBoostingClassifier(loss = 'log_loss',
                                                 learning_rate = 0.01,
                                                 max_features = x_train.shape[1],
                                                 criterion = 'friedman_mse',
                                                 random_state = 42)

# %%
# Cross-validation data splitting strategy
kf_boosting = KFold(n_splits = 2, shuffle = True, random_state = 42)

# Defining a search grid

param_grid_boosting = {'n_estimators': list(range(1000, 5001, 50)),
                        'max_leaf_nodes': [2, 3, 4, 5, 6, 7]
}

# %%
# Cross-validation for all combinations to find the best set of parameters
cv_tree_class_boosting = GridSearchCV(estimator = Tree_class_boosting_estimator,
                                      param_grid = param_grid_boosting, 
                                      scoring = 'neg_log_loss',
                                      cv = kf_boosting, 
                                      n_jobs = -1).fit(x_train, y_train)

# %%
# Outputting the best combination
print("Best Parameters: ", cv_tree_class_boosting.best_params_)
print("Best Score: ", cv_tree_class_boosting.best_score_)
# Out:
# Best Parameters:  {'max_leaf_nodes': 6, 'n_estimators': 1650}
# Best Score:  -0.35249858290199554

# %%
# Using the best combination of parameters

Tree_class_boost_best = GradientBoostingClassifier(loss = 'log_loss',
                                                 learning_rate = 0.01,
                                                 n_estimators = 1650,
                                                 max_leaf_nodes = 6,
                                                 max_features = x_train.shape[1],
                                                 criterion = 'friedman_mse',
                                                 random_state = 42).fit(x_train, y_train)

# %%
# Output predicted class label for each observation in test data

print(Tree_class_boost_best.classes_)
print(Tree_class_boost_best.predict_proba(x_test))
pred_prob_test = Tree_class_boost_best.predict_proba(x_test)[:,1]
print(pred_prob_test)
# The output is an array that shows the probability of Y=0 (left) and the probability of Y=1 (right), respectively.

# How large for a predicted probability to be large enough for assigned to class 1? 
# We can write a loop to select the best cut-off probability.
# Out:
# [0 1]
# [[0.65414683 0.34585317]
#  [0.48853784 0.51146216]
#  [0.94854685 0.05145315]
#  ...
#  [0.28747857 0.71252143]
#  [0.84986689 0.15013311]
#  [0.23590347 0.76409653]]
# [0.34585317 0.51146216 0.05145315 ... 0.71252143 0.15013311 0.76409653]

# %%
# Selecting the optimal cut-off probability

# The cut-off probability begins at 0.1, increments by 0.01, and ends at 0.9.
Kappa_test_boost = []
cut_off_prob = []

for prob in np.arange(0.1, 0.91, 0.01):
    cut_off_prob.append(round(prob, 2))
    y_test_pred_class = np.where(pred_prob_test >= prob, 1, 0)
    Kappa = cohen_kappa_score(y1 = y_test_pred_class, y2 = y_test) 
    Kappa_test_boost.append(Kappa)
    
print(Kappa_test_boost.index(max(Kappa_test_boost))) # Get the index of the largest test Kappa
print(cut_off_prob[Kappa_test_boost.index(max(Kappa_test_boost))]) # Get the corresponding cut-off probability
print(max(Kappa_test_boost)) # Get the corresponding test Kappa

# Conclusion: the optimal cut-off probability is 0.38, giving us the best test Kappa of 0.514.
# Out:
# 28
# 0.38
# 0.518853565880776

# %%
# Training Kappa
pred_prob_train = Tree_class_boost_best.predict_proba(x_train)[:,1]
pred_class_train = np.where(pred_prob_train >= 0.38, 1, 0)
Kappa_train_boost = cohen_kappa_score(y1 = pred_class_train, y2 = y_train)
print(Kappa_train_boost)
# Out:
# 0.5698498325282015

# %%
# Test Kappa
pred_prob_test = Tree_class_boost_best.predict_proba(x_test)[:,1]
pred_class_test = np.where(pred_prob_test >= 0.38, 1, 0)
Kappa_test_boost = cohen_kappa_score(y1 = pred_class_test, y2 = y_test)
print(Kappa_test_boost)
# Out:
# 0.518853565880776

# %%
# Feature Importance
Gini_reduction = Tree_class_boost_best.feature_importances_

# Create a feature importance data frame
feature_importance_dict = {'feature_name': x_train.columns, 'Gini_reduction': Gini_reduction}
feature_importance_df = pd.DataFrame(feature_importance_dict).sort_values(by='Gini_reduction', ascending=False)

# Filter features with Gini reduction greater than 0.005
filtered_features_df = feature_importance_df[feature_importance_df['Gini_reduction'] > 0.005]

# Output the filtered features
print(filtered_features_df)
# Out:
#                        feature_name  Gini_reduction
# 2         Total Event Participation        0.360977
# 3            Count of Campus Visits        0.151382
# 26   Decision Plan_Early Decision I        0.124239
# 29         Athlete_Athlete, Opt Out        0.067084
# 27  Decision Plan_Early Decision II        0.052272
# 30              Athlete_Non-Athlete        0.050303
# 0                            Legacy        0.039456
# 4                    Academic Index        0.033812
# 6      Days_to_Submit_since_Inquiry        0.015647
# 70            Merit Award_Full Ride        0.010574
# 1                    Sport 1 Rating        0.007658
# 12  Permanent Country_United States        0.005528
# 81       ACT Composite Grouped_34.0        0.005524
# 82       ACT Composite Grouped_35.0        0.005198

# %%
# Training Kappa: 0.570
# Test Kappa: 0.519

# %% [markdown]
# # Bagging

# %%
# Bagging 

kf_bag_class_tree = KFold(n_splits = 10, shuffle = True, random_state = 42)

# %%
# Use the optimal tree size to fit a bagged classification tree
bag_class_tree_estimator = RandomForestClassifier(n_estimators=500, 
                                        criterion='gini', 
                                        max_depth = None,
                                        min_samples_split = 2,
                                        min_samples_leaf = 1, 
                                        max_leaf_nodes = None,
                                        max_features= x_train.shape[1], 
                                        bootstrap=True,
                                        max_samples = math.ceil(x_train.shape[0] * 0.9) -1,
                                        random_state = 42)

param_grid_bag_class_tree = {'max_leaf_nodes': list(range(2, 1676,250))}
                       
cv_bag_class_tree = GridSearchCV(estimator = bag_class_tree_estimator,
                              param_grid = param_grid_bag_class_tree, 
                              scoring = 'balanced_accuracy',
                              cv = kf_bag_class_tree,
                              n_jobs = -1) 
cv_bag_class_tree.fit(x_train, y_train)

print(cv_bag_class_tree.best_params_, cv_bag_class_tree.best_score_)
# Out:
# {'max_leaf_nodes': 252} 0.7067514288018935

# %%
bag_class_tree_best = RandomForestClassifier(n_estimators=500, 
                                        criterion='gini', 
                                        max_depth = None,
                                        min_samples_split = 2,
                                        min_samples_leaf = 1, 
                                        max_leaf_nodes = 252,
                                        max_features= x_train.shape[1], 
                                        bootstrap=True,
                                        max_samples = x_train.shape[0],
                                        random_state = 42).fit(x_train, y_train)

# %%
# Training Kappa of the optimal bagged tree
bag_class_tree_best_pred_train = bag_class_tree_best.predict(x_train)
Kappa_train_bag_class_tree_best = cohen_kappa_score(y1 = bag_class_tree_best_pred_train, y2 = y_train)
print(Kappa_train_bag_class_tree_best)
# Out:
# 0.7378852285076154

# %%
# Test Kappa of the optimal bagged tree
bag_class_tree_best_pred_test = bag_class_tree_best.predict(x_test)
Kappa_test_bag_class_tree_best = cohen_kappa_score(y1 = bag_class_tree_best_pred_test, y2 = y_test)
print(Kappa_test_bag_class_tree_best)
# Out:
# 0.4791460336625407

# %%
# Training Kappa: 0.738
# Test Kappa: 0.479

# %% [markdown]
# # Support vector machine - with Linear kernel

# %%
# Tune the C (cost) parameter using 10-fold cross-validation

from sklearn.svm import SVC

# Define the estimator
svml_estimator = SVC(kernel = 'linear', 
                 C = 1,
                 degree = 3,
                 gamma = 0.0)

# %%
# Define cross-validation data splitting strategy
kf_svml = KFold(n_splits = 5, shuffle = True, random_state = 42)

# %%
# Define base and power ranges
base_values = np.arange(2, 3, 1)  # From 2 to 3 (with a step size of 1)
power_values = np.arange(-5, 5.5, 1)  # From -5 to 5 with step size of 1

# Generate the search grid for the 'C' parameter
search_grid_svml = {'C': np.power.outer(base_values, power_values, dtype=complex)}

# Convert the grid into a 1D array and extract the real part (ignoring complex values)
search_grid_svml['C'] = search_grid_svml['C'].flatten().real

# Print the result
print(search_grid_svml)
# Out:
# {'C': array([3.125e-02, 6.250e-02, 1.250e-01, 2.500e-01, 5.000e-01, 1.000e+00,
#        2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01, 3.200e+01])}

# %%
# Cross-validation to find the best C value
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# Define the estimator: Linear SVM with 'linear' kernel
estimator = SVC(kernel='linear')

# Define the parameter grid for 'C'
search_grid_svml = {'C': np.power.outer(base_values, power_values, dtype=complex).flatten().real}

# Define the cross-validation procedure with GridSearchCV
cv_svml = GridSearchCV(estimator=estimator, 
                       param_grid=search_grid_svml, 
                       scoring='accuracy', 
                       cv=5,  # 5-fold cross-validation
                       n_jobs=-1)  # Use all available cores for parallelism

# Fit the model using the training data
cv_svml.fit(x_train, y_train)

# Output the best parameter and best score
print(f"Best C value: {cv_svml.best_params_['C']}")
print(f"Best cross-validation accuracy: {cv_svml.best_score_}")
# Out:
# Best C value: 0.0625
# Best cross-validation accuracy: 0.8329000000000001

# %%
# Fit a SVM with linear kernel model using the best C

svm_linear_best = SVC(kernel = 'linear', 
                 C = 0.0625,
                 degree = 3,
                 gamma = 0.0).fit(x_train, y_train)

# %%
# Classification Performance using the best model
# Training Kappa
svml_best_pred_train = svm_linear_best.predict(x_train)
Kappa_train_svml_best = cohen_kappa_score(y1 = svml_best_pred_train, y2 = y_train)
print("Training Kappa:", Kappa_train_svml_best)

# Test Kappa
svml_best_pred_test = svm_linear_best.predict(x_test)
Kappa_test_svml_best = cohen_kappa_score(y1 = svml_best_pred_test, y2 = y_test)
print("Test Kappa:", Kappa_test_svml_best)

# Training Kappa: 0.425
# Test Kappa: 0.405
# Out:
# Training Kappa: 0.42445572303223156
# Test Kappa: 0.40530622729441124
